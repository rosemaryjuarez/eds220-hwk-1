# %% [markdown]
# # Task 3
#
# First, update the following cell to have a link to your Homework 1 GitHub repository:

# %% [markdown]
# **UPDATE THIS LINK:**
#
# [https://github.com/rosemaryjuarez/eds220-hwk-1]()

# %% [markdown]
# In this task, make at least 5 commits at moments you think are adequate. We'll look at your repo to check commit history.
#
# Add comments for all your code. Err on the side of commenting too much for now.
#
# Comments in each exercise and commits will count towards your grade.
#
# This task covers topics we will see on Monday Oct. 9. The best strategy to solve it is to get together with your classmates and work on it together after Monday's lecture.

# %% [markdown]
# ## 1
# For this task we are going to use data about  [Western Indian Ocean Coral Diversity (McClanahan, 2023)](https://knb.ecoinformatics.org/view/doi%3A10.5063%2FF1K35S3H) from the Knowledge Network for Biocomplexity (KNB) data repository.
#
# a. Navigate to the dataset's link and explore the data package.
#
# b. Use the next markdown cell to add a brief description of the dataset, including a citation, date of access, and a link to the archive.

# %% [markdown]
# **description**: the dataset is on coral cover and number of “genera” in the Western Indian Ocean. Used to collect sample on coral bleaching. The data includes the coral reef locations, number of coral taxa, and climate change, water quality, human resource management and extraction variables for each 6.25km2 reef cell averaged over the 1998-2022 sampling period.
#
#
#
# **citation**:
# Tim McClanahan. (2023). Western Indian Ocean Coral Diversity. Knowledge Network for Biocomplexity. doi:10.5063/F1K35S3H.
#
# **date of access**: 10/12/2023
#
# **link**: https://knb.ecoinformatics.org/knb/d1/mn/v2/object/urn%3Auuid%3Ae7d12a5a-f1a9-4a3e-aaa5-5222f67e799d

# %% [markdown]
# ## 2
# In the next code cell, import the pandas package using standard abbreviation in a code cell.
#
# Read in the data from the URL using the `pd.read_csv` function and store it as `coral_div` like this:
#
# ```
# # read in data
# coral_div = pd.read_csv('the URL goes here')
# ```

# %%
import pandas as pd # importing pandas as pd

# %%
# importing coral data using url
coral_div = pd.read_csv('https://knb.ecoinformatics.org/knb/d1/mn/v2/object/urn%3Auuid%3Ae7d12a5a-f1a9-4a3e-aaa5-5222f67e799d')
# this will show all column names 
pd.set_option('display.max_columns', None) 
#use head() to see first 5
coral_div.head()
# Out:
#    PU_ID     PU_Lat    PU_Lon  Number_of_genera   Country  \
# 0      7  39.076711 -5.490011                35  Tanzania
# 1      7  39.076711 -5.490011                22  Tanzania
# 2      7  39.076711 -5.490011                25  Tanzania
# 3      7  39.076711 -5.490011                26  Tanzania
# 4     10  39.054253 -5.512514                27  Tanzania
#
#                   Ecoregion   Management           Habitat Observer  Depth  \
# 0  East African Coral Coast  UnfishedLow             Crest      Tim   11.0
# 1  East African Coral Coast  UnfishedLow  Lagoon/Back reef  Nyawira    2.0
# 2  East African Coral Coast  UnfishedLow             Slope  Nyawira    4.0
# 3  East African Coral Coast  UnfishedLow             Slope  Nyawira    3.0
# 4  East African Coral Coast  UnfishedLow  Lagoon/Back reef  Nyawira    1.5
#
#    Coralcover  SSTRateofRise     PARmax   Calcite  Dis_oxygen  mean.waveNRJ  \
# 0          45       0.019214  54.747001  0.001075      4.7495      3.714321
# 1          45       0.019214  54.747001  0.001075      4.7495      3.714321
# 2          45       0.019214  54.747001  0.001075      4.7495      3.714321
# 3          45       0.019214  54.747001  0.001075      4.7495      3.714321
# 4          48       0.020051  55.395000  0.001747      4.7510      3.270938
#
#    Salinity_mean  andrello_reef_value  andrello_nutrients     mean.npp  \
# 0      35.167646                    0            8.388602  1139.112671
# 1      35.167646                    0            8.388602  1139.112671
# 2      35.167646                    0            8.388602  1139.112671
# 3      35.167646                    0            8.388602  1139.112671
# 4      35.102688                    0            6.731860  1126.355957
#
#    TT_market_hrs  TT_pop_hrs     cumDHW  SST_Kurtosis  SST_Median  \
# 0       1.383333    0.366667  24.133263     -0.803330      27.435
# 1       1.383333    0.366667  24.133263     -0.803330      27.435
# 2       1.383333    0.366667  24.133263     -0.803330      27.435
# 3       1.383333    0.366667  24.133263     -0.803330      27.435
# 4       1.383333    0.366667  25.342901     -0.793681      27.455
#
#    ChlorA_median  andrello_sediments  Current_vel_mean  Diff_attenuation  \
# 0       0.465182         53540.00781          0.541991           0.09475
# 1       0.465182         53540.00781          0.541991           0.09475
# 2       0.465182         53540.00781          0.541991           0.09475
# 3       0.465182         53540.00781          0.541991           0.09475
# 4       0.700521         38477.10547          0.690454           0.11400
#
#     Grav_NP   Grav_NC      PH  SST_bimodality  SST_Skewness  \
# 0  0.008503  32.38792  8.2175        0.462556     -0.128136
# 1  0.008503  32.38792  8.2175        0.462556     -0.128136
# 2  0.008503  32.38792  8.2175        0.462556     -0.128136
# 3  0.008503  32.38792  8.2175        0.462556     -0.128136
# 4  0.008503  32.38792  8.2180        0.461297     -0.134548
#
#    ClimateStressModel   Netflow  Indegree  Outdegree  Retention  min_yr  \
# 0            0.596375  0.144498     98.25      74.75      14.00    2019
# 1            0.596375  0.144498     98.25      74.75      14.00    2010
# 2            0.596375  0.144498     98.25      74.75      14.00    2015
# 3            0.596375  0.144498     98.25      74.75      14.00    2016
# 4            0.629000  0.011721    112.75      51.50     183.75    2010
#
#    max_yr  no_replicates
# 0    2019              1
# 1    2015              2
# 2    2015              1
# 3    2019              2
# 4    2019              3

# %% [markdown]
# ## 3
#
# Use attributes and methods of the `coral_div` data frame to obtain the following information about it:
#
# a. how many rows and columns does it have?
#
# b. what are the column names?
#
# c. what are the data types of the columns?
#
# d. display the first 8 rows with all the column names. For this one, you will need to udpate a `pandas` option (see discussion section)
#
# e. some inital info you are interested in.
#
# Use the code cells marked a-e. For each, add a comment explaining what is the ouput.

# %%
# a) there are 575 rows and 42 columns
coral_div.shape
# Out:
# (575, 42)

# %%
# b 
coral_div.columns

#column names are" PU_ID', 'PU_Lat', 'PU_Lon', 
#'Number_of_genera', 'Country', 'Ecoregion','Management', 
#'Habitat', 'Observer', 'Depth', 'Coralcover','SSTRateofRise', 
#'PARmax', 'Calcite', 'Dis_oxygen', 'mean.waveNRJ','Salinity_mean', 
#'andrello_reef_value', 'andrello_nutrients','mean.npp', 'TT_market_hrs', 
#'TT_pop_hrs', 'cumDHW', 'SST_Kurtosis','SST_Median', 'ChlorA_median', 
#'andrello_sediments', 'Current_vel_mean','Diff_attenuation', 'Grav_NP', 
#'Grav_NC', 'PH', 'SST_bimodality','SST_Skewness', 'ClimateStressModel', 'Netflow', 
#'Indegree','Outdegree', 'Retention', 'min_yr', 'max_yr', 'no_replicates'],
# Out:
# Index(['PU_ID', 'PU_Lat', 'PU_Lon', 'Number_of_genera', 'Country', 'Ecoregion',
#        'Management', 'Habitat', 'Observer', 'Depth', 'Coralcover',
#        'SSTRateofRise', 'PARmax', 'Calcite', 'Dis_oxygen', 'mean.waveNRJ',
#        'Salinity_mean', 'andrello_reef_value', 'andrello_nutrients',
#        'mean.npp', 'TT_market_hrs', 'TT_pop_hrs', 'cumDHW', 'SST_Kurtosis',
#        'SST_Median', 'ChlorA_median', 'andrello_sediments', 'Current_vel_mean',
#        'Diff_attenuation', 'Grav_NP', 'Grav_NC', 'PH', 'SST_bimodality',
#        'SST_Skewness', 'ClimateStressModel', 'Netflow', 'Indegree',
#        'Outdegree', 'Retention', 'min_yr', 'max_yr', 'no_replicates'],
#       dtype='object')

# %%
# c 
coral_div.info()
#the data type of the objects are as follows in this output: integers, floats, and objects
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 575 entries, 0 to 574
# Data columns (total 42 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   PU_ID                575 non-null    int64
#  1   PU_Lat               575 non-null    float64
#  2   PU_Lon               575 non-null    float64
#  3   Number_of_genera     575 non-null    int64
#  4   Country              575 non-null    object
#  5   Ecoregion            575 non-null    object
#  6   Management           575 non-null    object
#  7   Habitat              530 non-null    object
#  8   Observer             575 non-null    object
#  9   Depth                575 non-null    float64
#  10  Coralcover           575 non-null    int64
#  11  SSTRateofRise        575 non-null    float64
#  12  PARmax               575 non-null    float64
#  13  Calcite              575 non-null    float64
#  14  Dis_oxygen           575 non-null    float64
#  15  mean.waveNRJ         575 non-null    float64
#  16  Salinity_mean        575 non-null    float64
#  17  andrello_reef_value  575 non-null    int64
#  18  andrello_nutrients   575 non-null    float64
#  19  mean.npp             575 non-null    float64
#  20  TT_market_hrs        575 non-null    float64
#  21  TT_pop_hrs           575 non-null    float64
#  22  cumDHW               575 non-null    float64
#  23  SST_Kurtosis         575 non-null    float64
#  24  SST_Median           575 non-null    float64
#  25  ChlorA_median        575 non-null    float64
#  26  andrello_sediments   575 non-null    float64
#  27  Current_vel_mean     567 non-null    float64
#  28  Diff_attenuation     575 non-null    float64
#  29  Grav_NP              575 non-null    float64
#  30  Grav_NC              575 non-null    float64
#  31  PH                   575 non-null    float64
#  32  SST_bimodality       575 non-null    float64
#  33  SST_Skewness         575 non-null    float64
#  34  ClimateStressModel   575 non-null    float64
#  35  Netflow              575 non-null    float64
#  36  Indegree             575 non-null    float64
#  37  Outdegree            575 non-null    float64
#  38  Retention            575 non-null    float64
#  39  min_yr               575 non-null    int64
#  40  max_yr               575 non-null    int64
#  41  no_replicates        575 non-null    int64
# dtypes: float64(30), int64(7), object(5)
# memory usage: 188.8+ KB

# %%
# d already set column names as visible in question 4
coral_div.head(8)
# Out:
#    PU_ID     PU_Lat    PU_Lon  Number_of_genera   Country  \
# 0      7  39.076711 -5.490011                35  Tanzania
# 1      7  39.076711 -5.490011                22  Tanzania
# 2      7  39.076711 -5.490011                25  Tanzania
# 3      7  39.076711 -5.490011                26  Tanzania
# 4     10  39.054253 -5.512514                27  Tanzania
# 5     10  39.054253 -5.512514                29  Tanzania
# 6     15  39.054253 -5.535017                19  Tanzania
# 7     39  39.009337 -5.647518                28  Tanzania
#
#                   Ecoregion   Management           Habitat Observer  Depth  \
# 0  East African Coral Coast  UnfishedLow             Crest      Tim   11.0
# 1  East African Coral Coast  UnfishedLow  Lagoon/Back reef  Nyawira    2.0
# 2  East African Coral Coast  UnfishedLow             Slope  Nyawira    4.0
# 3  East African Coral Coast  UnfishedLow             Slope  Nyawira    3.0
# 4  East African Coral Coast  UnfishedLow  Lagoon/Back reef  Nyawira    1.5
# 5  East African Coral Coast  UnfishedLow  Lagoon/Back reef      Tim    1.5
# 6  East African Coral Coast   Restricted             Crest      Tim    8.0
# 7  East African Coral Coast  UnfishedLow  Lagoon/Back reef  Nyawira
# 0    2019              1
# 1    2015              2
# 2    2015              1
# 3    2019              2
# 4    2019              3
# 5    2015              1
# 6    2019              1
# 7    2019              3

# %%
# e)

# im interested to see more on the relationship between habitat, coral cover, and salinity.

#commit # 1

# %% [markdown]
# ## 4
#
# Some of the columns have data type `int64` and some have data type `float64`. What is the difference between these `int64` and `float64`?

# %% [markdown]
# The difference is that integers are whole numbers, and they tend to only be used for discrete variables. While float64 are for numbers with decimals. This means we can have a long range of infinite numbers (continuous).

# %% [markdown]
# ## 5
#
# The `Country` column indicates the country of reef location. Explain in your words what is the ouput of `coral_div.Country` and `coral_div.Country.unique()`.

# %%
coral_div.Country
coral_div.Country.unique() # this is not like nunique, that is differnet! that does a count
# Out:
# array(['Tanzania', 'Mozambique', 'Kenya', 'Reunion', 'Comoros', 'Mayotte',
#        'French Southern Territories', 'Madagascar', 'Seychelles',
#        'South Africa', 'Mauritius'], dtype=object)

# %% [markdown]
# when running `coral_div.Country`, I received a series of all the recorded countries. Meanwhile, `coral_div.unique` gives me an output that shows which countries are within the list.

# %% [markdown]
# ## 6
#
# Check the dataset's [metadata file README_md.doc](https://knb.ecoinformatics.org/view/doi:10.5063/F1K35S3H) to find which column has information about who made an observation. How many observers collected this data? HINT: use the `len` Python function. Not sure what `len` does? Use `?`.

# %%
# the Observers column tells us the name of the observers who collectged the data. 

len(coral_div.Observer.unique())

#the number of unique observers are 16.
# Out:
# 16

# %% [markdown]
# ## 7
#
# The `Coralcover` column indicates the percent of hard coral cover in each 6km reef cell surveyed. What data is `coral_div[coral_div['Coralcover'] >= 50]` selecting?

# %%
coral_div[coral_div['Coralcover'] >= 50]

#this is selecting coral cover that is about 50% or more, using indexing and conditionals to achieve this.

# commit #2
# Out:
#      PU_ID     PU_Lat     PU_Lon  Number_of_genera     Country  \
# 39     220  39.233916  -6.658981                17    Tanzania
# 40     220  39.233916  -6.658981                19    Tanzania
# 41     221  39.256374  -6.658981                25    Tanzania
# 42     221  39.256374  -6.658981                19    Tanzania
# 43     221  39.256374  -6.658981                12    Tanzania
# ..     ...        ...        ...               ...         ...
# 303   4039  48.082322 -13.553193                27  Madagascar
# 304   4039  48.082322 -13.553193                20  Madagascar
# 305   4039  48.082322 -13.553193                21  Madagascar
# 306   4039  48.082322 -13.553193                33  Madagascar
# 514   6064  40.603847 -12.496246                30  Mozambique
#
#                            Ecoregion   Management           Habitat Observer  \
# 39          East African Coral Coast  UnfishedLow             Slope  Nyawira
# 40          East African Coral Coast  UnfishedLow             Slope      Tim
# 41          East African Coral Coast  UnfishedLow  Lagoon/Back reef  Nyawira
# 42          East African Coral Coast  UnfishedLow  Lagoon/Back reef      Tim
# 43          East African Coral Coast  UnfishedLow  Lagoon/Back reef  Nyawira
# ..                               ...          ...               ...      ...
# 303  Western and Northern Madagascar  UnfishedLow             Slope  Arielle
# 304  Western and Northern Madagascar  UnfishedLow             Slope  D'Agata
# 305  Western and Northern Madagascar  UnfishedLow             Slope   Julien
# 306  Western and Northern Madagascar  UnfishedLow             Slope  Nyawira
# 514         East African Coral Coast  UnfishedLow  Lagoon/Back reef  Nyawira
# ..                ...       ...          ...     ...             ...
# 303           0.15100  0.819690     0.648977  8.2025        0.566251
# 304           0.15100  0.819690     0.648977  8.2025        0.566251
# 305           0.15100  0.819690     0.648977  8.2025        0.566251
# 306           0.15100  0.819690     0.648977  8.2025        0.566251
# 514           0.09500  0.006355     2.553257  8.2030        0.529942
#
#      SST_Skewness  ClimateStressModel   Netflow  Indegree  Outdegree  \
# 39      -0.171423             0.62130 -0.443779    127.50      62.25
# 40      -0.171423             0.62130 -0.443779    127.50      62.25
# 41      -0.169093             0.52760 -0.443779    127.50      62.25
# 42      -0.169093             0.52760 -0.443779    127.50      62.25
# 43      -0.169093             0.52760 -0.443779    127.50      62.25
# ..            ...                 ...       ...       ...        ...
# 303     -0.271831             0.72960  0.670117     12.50      29.00
# 304     -0.271831             0.72960  0.670117     12.50      29.00
# 305     -0.271831             0.72960  0.670117     12.50      29.00
# 306     -0.271831             0.72960  0.670117     12.50      29.00
# 514     -0.145626             0.68105  0.116857     54.75      54.25
#
#      Retention  min_yr  max_yr  no_replicates
# 39      204.75    2016    2016              1
# 40      204.75    2012    2019              3
# 41      204.75    2016    2016              1
# 42      204.75    2016    2016              1
# 43      204.75    2016    2016              1
# ..         ...     ...     ...            ...
# 303      62.50    2017    2019              3
# 304      62.50    2016    2016              2
# 305      62.50    2016    2016              1
# 306      62.50    2015    2015              1
# 514     126.50    2015    2015              1
#
# [67 rows x 42 columns]

# %% [markdown]
# ## 8
#
# Use code to find if there are there any sites with a 30% coral cover in Tanzania.

# %%
coral_div[(coral_div['Coralcover'] == 30) &  (coral_div['Country'] == 'Tanzania')]

#used code to find 30% coral cover in Tanzania
# Out:
#      PU_ID     PU_Lat    PU_Lon  Number_of_genera   Country  \
# 63     693  39.391121 -5.782490                10  Tanzania
# 64     697  39.391121 -5.804983                22  Tanzania
# 341   4294  39.211458 -4.814515                37  Tanzania
# 342   4299  39.233916 -4.837043                26  Tanzania
# 343   4302  39.211458 -4.859570                31  Tanzania
# 344   4303  39.301290 -4.859570                23  Tanzania
# 377   4906  39.660616 -4.972195                33  Tanzania
# 388   5049  39.615700 -5.490011                14  Tanzania
# 389   5050  39.638158 -5.490011                18  Tanzania
#
#                     Ecoregion Management           Habitat Observer  \
# 63   East African Coral Coast     Fished  Lagoon/Back reef  Nyawira
# 64   East African Coral Coast     Fished  Lagoon/Back reef  Nyawira
# 341  East African Coral Coast     Fished             Slope  Nyawira
# 342  East African Coral Coast     Fished             Slope  Nyawira
# 343  East African Coral Coast     Fished             Slope  Nyawira
# 344  East African Coral Coast     Fished             Slope  Nyawira
# 377  East African Coral Coast     Fished  Lagoon/Back reef  Nyawira
# 388  East African Coral Coast     Fished  Lagoon/Back reef  Nyawira
# 389  East African Coral Coast     Fished  Lagoon/Back reef  Nyawira
#
#          Depth  Coralcover  SSTRateofRise     PARmax   Calcite  Dis_oxygen  \
# 63    5.000000          30       0.015676  52.992001  0.037043      4.7580
# 64    9.166667          30       0.015599  52.992001  0.037043      4.7580
# 341  11.000000          30       0.018789  53.858002  0.002154      4.7170
# 342  12.500000          30       0.018789  53.937000  0.001265      4.7195
# 343   7.000000          30       0.018462  54.015999  0.000377      4.7220
# 344  11.000000          30       0.018270  53.937000  0.002104      4.7220
# 377   9.000000          30       0.016549  53.943001  0.000076      4.7270
# 64      147.50    2010    2018              3
# 341      82.75    2018    2018              1
# 342      82.75    2018    2018              2
# 343      82.75    2018    2018              1
# 344      82.75    2018    2018              1
# 377      38.00    2013    2013              2
# 388     650.25    2018    2018              1
# 389     650.25    2018    2018              1

# %% [markdown]
# ## 9
#
# We are interested in looking at the PH of sea water (`PH` column),  mean salinity (PSS) (`Salinity_mean` column), and depth of survey location in meters (`Depth` column). Select this data.

# %%
new = coral_div[['PH', 'Salinity_mean', 'Depth']]
new
# Out:
#          PH  Salinity_mean  Depth
# 0    8.2175      35.167646  11.00
# 1    8.2175      35.167646   2.00
# 2    8.2175      35.167646   4.00
# 3    8.2175      35.167646   3.00
# 4    8.2180      35.102688   1.50
# ..      ...            ...    ...
# 570  8.2400      35.301208  15.50
# 571  8.2400      35.301208  12.00
# 572  8.2400      35.301208  12.60
# 573  8.2400      35.301208  13.00
# 574  8.2400      35.301208  13.47
#
# [575 rows x 3 columns]

# %% [markdown]
# ## 10
# The `max_yr` column indicates the year of last sampling at a given site. Select the PH, salinity, and depth for sites where sampling ended in 2017.

# %%
# selecting columns and setting a variable name
new_one = coral_div[['PH', 'Salinity_mean', 'Depth', 'max_yr']]

#selecting with conditions
new_one[coral_div['max_yr'] == 2017]
# Out:
#          PH  Salinity_mean      Depth  max_yr
# 67   8.2150      35.100085  16.000000    2017
# 68   8.2145      35.144927  10.000000    2017
# 70   8.2150      35.101086  11.000000    2017
# 71   8.2150      35.101086  11.000000    2017
# 72   8.2150      35.101086   9.000000    2017
# 73   8.2150      35.101086   9.000000    2017
# 84   8.2110      35.278084  12.500000    2017
# 85   8.2110      35.278084   6.000000    2017
# 164  8.2220      35.337914   9.875000    2017
# 167  8.2220      35.337914  12.075000    2017
# 169  8.2220      35.337914  10.300000    2017
# 172  8.2220      35.337914  11.000000    2017
# 174  8.2225      35.287419   7.266667    2017
# 176  8.2225      35.287419  13.225000    2017
# 179  8.2225      35.287419  10.550000    2017
# 182  8.2220      35.331669  12.033333    2017
# 185  8.2230      35.374460  10.900000    2017
# 188  8.2230      35.374460  14.725000    2017
# 191  8.2230      35.247482   9.725000    2017
# 194  8.2230      35.341358  11.075000    2017
# 197  8.2230      35.390354  10.600000    2017
# 346  8.2165      35.114244   7.000000    2017
# 347  8.2165      35.112398   3.000000    2017
# 348  8.2165      35.112398   4.000000    2017
# 349  8.2160      35.117374   5.500000    2017
# 350  8.2160      35.117374   2.000000    2017
# 351  8.2160      35.117374  15.000000    2017
# 352  8.2160      35.117374   5.000000    2017
# 353  8.2165      35.149462  11.000000    2017
# 354  8.2160      35.270199   9.000000    2017
# 395  8.2400      35.276642   9.416667    2017
# 559  8.2120      35.204185   1.500000    2017
# 566  8.2400      35.301208  17.000000    2017
# 569  8.2400      35.301208  13.833333    2017
# 574  8.2400      35.301208  13.470000    2017

# %% [markdown]
# ## 11
# Use `iloc` to select rows 95 throuhg 100 (including 100) in the 17th, 20th, and 28th columns and assign these values to a new variable called `subset`. HINT: the ouput columns should be `Salinity_mean`, `mean.npp` and `Current_vel_mean`. Are you indexing from 0?

# %%
coral_div.iloc[94:101, [16,19, 27]] # i selected the rows. I had trouble with the columns until i realized i
# can use a list within a list
# Out:
#      Salinity_mean     mean.npp  Current_vel_mean
# 94       35.201630  1365.146729          0.878417
# 95       35.201630  1365.146729          0.878417
# 96       35.204185  1117.635010          0.839372
# 97       35.234774  1105.270142          0.685955
# 98       35.234774  1105.270142          0.685955
# 99       35.250068  1082.196411               NaN
# 100      35.250068  1082.196411               NaN

# %% [markdown]
# ## 12
#
# Run `subset.isna()`. Explain what this code does and what the output represents.

# %% [markdown]
# .isna() is a function that goes through the dataframe and figure out if it has NA values. it returns back boolean values in your dataframe

# %%
coral_div.isna() # it is boolean
# Out:
#      PU_ID  PU_Lat  PU_Lon  Number_of_genera  Country  Ecoregion  Management  \
# 0    False   False   False             False    False      False       False
# 1    False   False   False             False    False      False       False
# 2    False   False   False             False    False      False       False
# 3    False   False   False             False    False      False       False
# 4    False   False   False             False    False      False       False
# ..     ...     ...     ...               ...      ...        ...         ...
# 570  False   False   False             False    False      False       False
# 571  False   False   False             False    False      False       False
# 572  False   False   False             False    False      False       False
# 573  False   False   False             False    False      False       False
# 574  False   False   False             False    False      False       False
#
#      Habitat  Observer  Depth  Coralcover  SSTRateofRise  PARmax  Calcite  \
# 0      False     False  False       False          False   False    False
# 1      False     False  False       False          False   False    False
# 2      False     False  False       False          False   False    False
# 3      False     False  False       False          False   False    False
# 4      False     False  False       False          False   False    False
# ..       ...       ...    ...         ...            ...     ...      ...
# 570    False     False  False       False          False   False    False
# 571    False     False  False       False          False   False    False
# 572    False     False  False       False          False   False    False
# 573    False     False  False       False          False   False    False
# 574    False     False  False       False          False   False    False
#
#      Dis_oxygen  mean.waveNRJ  Salinity_mean  andrello_reef_value  \
# 0         False         False          False                False
# 1         False         False          False                False
# 2         False         False          False                False
# 3         False         False          False                False
# 4         False         False          False                False
# ..          ...           ...            ...                  ...
# 570       False         False          False                False
# 571       False         False          False                False
# 572       False         False          False                False
# 573       False         False          False                False
# 574       False         False          False                False
#
#      andrello_nutrients  mean.npp  TT_market_hrs  TT_pop_hrs  cumDHW  \
# 0                 False     False          False       False   False
# 1                 False     False          False       False   False
# 2                 False     False          False       False   False
# 3                 False     False          False       False   False
# 4                 False     False          False       False   False
# ..                  ...       ...            ...         ...     ...
# 570               False     False          False       False   False
# 571               False     False          False       False   False
# 572               False     False          False       False   False
# 573               False     False          False       False   False
# 574               False     False          False       False   False
#
#      SST_Kurtosis  SST_Median  ChlorA_median  andrello_sediments  \
# 0           False       False          False               False
# 1           False       False          False               False
# 2           False       False          False               False
# 3           False       False          False               False
# 4           False       False          False               False
# ..            ...         ...            ...                 ...
# 570         False       False          False               False
# 571         False       False          False               False
# 572         False       False          False               False
# 573         False       False          False               False
# 574         False       False          False               False
#
#      Current_vel_mean  Diff_attenuation  Grav_NP  Grav_NC     PH  \
# 0               False             False    False    False  False
# 1               False             False    False    False  False
# 2               False             False    False    False  False
# 3               False             False    False    False  False
# 4               False             False    False    False  False
# ..                ...               ...      ...      ...    ...
# 570             False             False    False    False  False
# 571             False             False    False    False  False
# 572             False             False    False    False  False
# 573             False             False    False    False  False
# 574             False             False    False    False  False
#
#      SST_bimodality  SST_Skewness  ClimateStressModel  Netflow  Indegree  \
# 0             False         False               False    False     False
# 1             False         False               False    False     False
# 2             False         False               False    False     False
# 3             False         False               False    False     False
# 4             False         False               False    False     False
# ..              ...           ...                 ...      ...       ...
# 570           False         False               False    False     False
# 571           False         False               False    False     False
# 572           False         False               False    False     False
# 573           False         False               False    False     False
# 574           False         False               False    False     False
#
#      Outdegree  Retention  min_yr  max_yr  no_replicates
# 0        False      False   False   False          False
# 1        False      False   False   False          False
# 2        False      False   False   False          False
# 3        False      False   False   False          False
# 4        False      False   False   False          False
# ..         ...        ...     ...     ...            ...
# 570      False      False   False   False          False
# 571      False      False   False   False          False
# 572      False      False   False   False          False
# 573      False      False   False   False          False
# 574      False      False   False   False          False
#
# [575 rows x 42 columns]

# %% [markdown]
# ## 13
# Run `subset.isna().any()`. Explain what this code does and what the output represents. HINT: It could be helpful to check the [documentation of `pandas.Sries.any`](https://pandas.pydata.org/docs/reference/api/pandas.Series.any.html).

# %% [markdown]
# *Update this markdown cell with your answer.*

# %%
coral_div.isna().any()
# it is used to tell if there is any non-zero value present in the given series object(it is boolean).
#it seems that Habitat has non-zero values in its observations, while the rest do, meaning there are some NAs
#in all the data, except for habitat
# Out:
# PU_ID                  False
# PU_Lat                 False
# PU_Lon                 False
# Number_of_genera       False
# Country                False
# Ecoregion              False
# Management             False
# Habitat                 True
# Observer               False
# Depth                  False
# Coralcover             False
# SSTRateofRise          False
# PARmax                 False
# Calcite                False
# Dis_oxygen             False
# mean.waveNRJ           False
# Salinity_mean          False
# andrello_reef_value    False
# andrello_nutrients     False
# mean.npp               False
# TT_market_hrs          False
# TT_pop_hrs             False
# cumDHW                 False
# SST_Kurtosis           False
# SST_Median             False
# ChlorA_median          False
# andrello_sediments     False
# Current_vel_mean        True
# Diff_attenuation       False
# Grav_NP                False
# Grav_NC                False
# PH                     False
# SST_bimodality         False
# SST_Skewness           False
# ClimateStressModel     False
# Netflow                False
# Indegree               False
# Outdegree              False
# Retention              False
# min_yr                 False
# max_yr                 False
# no_replicates          False
# dtype: bool

# %% [markdown]
# ## 14
#
# Select the rows in `subset` that have NA in the `Current_vel_mean` column. HINT: you can use your answer for 9.

# %%
# solve exercise here
selection = coral_div['Current_vel_mean']
selection[selection.isna() == True] # proud of myself for figuring it out
# looks like there are only a couple of rows where i have some NA value
# Out:
# 99    NaN
# 100   NaN
# 423   NaN
# 430   NaN
# 431   NaN
# 432   NaN
# 433   NaN
# 434   NaN
# Name: Current_vel_mean, dtype: float64

# %%
# commit time
